# %% [markdown]
# # 파이썬 기본문법

# %% [markdown]
# ## 출력

# %%
print("이름 나이 지역")
# Out:
# 이름 나이 지역

# %%
print("이름\t나이\t지역")
# Out:
# 이름	나이	지역

# %%
print('\\')
# Out:
# \

# %%
print('/')
# Out:
# /

# %%
print('동해물과 백두산이 마르고 달토록\n하느님이 보우하사 우리나라 만세')
# Out:
# 동해물과 백두산이 마르고 달토록
# 하느님이 보우하사 우리나라 만세

# %%
print('''
동해물과 백두산이 마르고 달토록
하느님이 보우하사 우리나라 만세
''')

# %%
"사과"+"바나나"
# Out:
# '사과바나나'

# %%
5+5.2
# Out:
# 10.2

# %%
num = 2
num
# Out:
# 2

# %% [markdown]
# - 숫자 -> 문자로 변환 : 형변환, casting

# %%
num = str(num)

# %%
num
# Out:
# '2'

# %%
type(num)
# Out:
# str

# %% [markdown]
# # 문자열 인덱싱

# %%
data_str = "김경하"

# %%
data_str
# Out:
# '김경하'

# %%
data_str[0]
# Out:
# '김'

# %%
data_str[1]
# Out:
# '경'

# %%
data_str[2]
# Out:
# '하'

# %%
# 인덱스 범위를 벗나서 익덱싱을 하면 오류남
data_str[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-8253687a04fa> in <cell line: 1>()
# ----> 1 data_str[3]
#
# IndexError: string index out of range

# %%
data_str[0:]
# Out:
# '김경하'

# %%
data_str[1:]
# Out:
# '경하'

# %%
# 0 ~ 2-1까지 슬라이싱
data_str[:2]
# Out:
# '김경'

# %% [markdown]
# # 사용자로부터 자료 입력받기

# %%
vals = input()
# Out:
# 홍길동

# %%
vals
# Out:
# '홍길동'

# %%
nums = input("숫자를 넣으세요 >> ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-d49a01eefb50> in <cell line: 1>()
# ----> 1 nums = input("숫자를 넣으세요 >> ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
# ...

# %%
print(nums)
print(type(nums))
# Out:
# 12
# <class 'str'>

# %%
nums = int(nums)
type(nums)
nums
# Out:
# 12

# %%
float(nums)
# Out:
# 12.0

# %%
num1 = input("숫자를 넣으세요 >> ")
# Out:
# 숫자를 넣으세요 >> 12

# %%
num1 = eval(num1)
type(num1)
# Out:
# int

# %%
print("-"*20)
# Out:
# --------------------

# %% [markdown]
# # 문제1

# %%
print(num1)
# Out:
# 12

# %%
print("두 수의 사칙 연산 결과")
print("-"*20)
print(f"{num1} + {nums} = {num1 + nums}")
print(f"{num1} - {nums} = {num1 - nums}")
print(f"{num1} * {nums} = {num1 * nums}")
print(f"{num1} / {nums} = {num1 / nums}")
print(f"{num1} % {nums} = {num1 % nums}")
print(f"{num1} // {nums} = {num1 // nums}")
# Out:
# 두 수의 사칙 연산 결과
# --------------------
# 12 + 12 = 24
# 12 - 12 = 0
# 12 * 12 = 144
# 12 / 12 = 1.0
# 12 % 12 = 0
# 12 // 12 = 1
